# %% [markdown]
# <a href="https://colab.research.google.com/github/eswarigoru/dapreparation/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/saimalleshk/50_Startups
# Out:
# Cloning into '50_Startups'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 33 (delta 2), reused 0 (delta 0), pack-reused 22
# Unpacking objects: 100% (33/33), 361.63 KiB | 6.46 MiB/s, done.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
a=pd.read_csv("/content/50_Startups/50_Startups.csv")

# %%
a.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
a.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
sns.jointplot(data=a, x='R&D Spend',y='Profit')

# %%
sns.jointplot(data=a, x='Administration',y='Profit')

# %%
sns.jointplot(data=a, x='Marketing Spend',y='Profit')

# %%
sns.jointplot(data=a, x='Marketing Spend',y='Profit',kind='hex'),
# Out:
# (<seaborn.axisgrid.JointGrid at 0x7f25c599a800>,)

# %%
sns.pairplot(a)
sns.lmplot(data=a,x='R&D Spend',y='Profit')

# %%
sns.lmplot(data=a,x='R&D Spend',y='Profit')

# %%
X = a[['R&D Spend', 'Administration', 'Marketing Spend']]
Y = a['Profit']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.5, random_state=0)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
regressor.coef_
# Out:
# array([0.84085046, 0.01654303, 0.02554206])

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predictions = regressor.predict(X_test)
plt.scatter(Y_test, predictions)
plt.xlabel('Y_test(True Values)')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')
